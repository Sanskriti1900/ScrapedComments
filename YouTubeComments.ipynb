# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanskriti1900/ScrapedComments/blob/main/YouTubeComments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pull Comments

# %%
import googleapiclient.discovery
import googleapiclient.errors
import pandas as pd # Import the pandas library

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyDyUNc6YYQGahMp6rjmxwMIWr83fY5x3V8"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="eSpuWlI1_TQ",
    maxResults=50
)
response = request.execute()

# Define an empty list called 'comments' to store the extracted comment data
comments = []

for item in response['items']:
    print(item['snippet']['topLevelComment']['snippet']['textDisplay'])
    # Extract the desired information from each comment and append it to the 'comments' list
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])


df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

df.to_csv("YouTubeComments.csv", index=False)

print("CSV file has been generated and saved as 'YouTube_Comments.csv'")

from google.colab import files
df.to_csv("YouTube_Comments.csv", index=False)
files.download("YouTube_Comments.csv")
# Out:
# BACHPAN KE DIN SABSE ACCHE DIN , BACCHO KO DEKH KE APNA BACHPAN YAAD AA JAATA HAI. GOD BLESS U BETE.
# Where is muao
# Where is mau
# ड्रामा देख के बच्चे क्या सीखेंगे😂
# Sir baccho kj kab tak content ke liye istemal karenge
# Thanks you for 1.5 k subscriber
# Old vlogs ❤❤
# Very cheap Husband.
# Who is shivani?
# Rashi is more mature than her age. Maintain Good Parenting.
# AJ mana in ka vlog 3 Saal bad dakha 🥺
# It&#39;s so happy to see rashi grow❤
# Happy Birthday Dear Rituu❤❤
# Allah bless you all❤
# Rashi bahut hi jyada pyaar se bolti hai Swee t girl rsabhari chiklu
# Real kalesh tha na?
# Me too cheesecake with either black coffee or black tea best combination 😊
# Rashi is so clever
# DARNA JAROORI HAI<br>UR FAMILY MAN❤
# Chuyia bna rahey ho old videos daal key
# Gaurav bhai just sharing my own perspective, I used to like your vlogs without unnecessary sound effects like you did in the beginning of this vlog when pihu wanted to change her dress. Raw is better in vlogs
# Log kitne pagal ha dosre  ke life  ko dekne ma
# They all are good now good so that was fake😮
# Tum dono kalesh kalesh hi kehte ho ..u r educated come out of it
# Rashi ko chasma lag gaya. <br>Itna healthy ghee khane ke badh bhi
# konsa nasha karke editing kari bhaiya
# 🧿🧿🧿🧿🧿
# <a href="https://youtube.com/@neelomadhabpadhy7525?si=PdTn_d11SJMBqiaP">https://youtube.com/@neelomadhabpadhy7525?si=PdTn_d11SJMBqiaP</a>
# Najar na lage apki family ko.. Krishna har buri najar se bacchaye..
# Ab ptani pyaar hi dikhna band ho gya hai in dono ke beech.. Seems like they are just being very formal and unattached. Doing all of that just for the sake of formality and pressure. Else, during rashi’s childhood years real love and passion could be seen between the couple.
# Mao kaha hay
# what have the vlogs turned into...
# Bhaiyya mau kaha hai😢
# Gaurav bhaiya kitne ache h<br> Rashi pihu  k baad apni servant ko v khilaya fir khud khae
# Bhagwan ye jodi banaye rakhe❤
# last time i saw videos <br>You divorced Ritu mam<br>Ex wife ko firse wife bana liya😂
# Shaadi me jaldi pohchne ke faayde😂😂
# <a href="https://www.youtube.com/watch?v=eSpuWlI1_TQ&amp;t=570">9:30</a> Pihu 😂😂
# where is mau ??
# Mau kha gaya ???
# Where is mau?
# You have money but your children seem a bit deprived. Why so?
# Rashi is so cute 😂
# that blue tshirt since ages😂🤩
# To block corn use dnsforfamily( without enforcing it in YouTube)<br><br>In mobiles and router
# Where is mau?
# Ritu ji sir se bhut jyada pyar krti h unke aankho me dikhta h❤
# Happy bd Ritujiji
# Ritujiji deserves gift❤❤❤
# He can show is personal matters on social media with clickbait (false tag lines &amp; misleading thumbnail) but if any one talks about his personal life then both get offended. If you&#39;re on social media, pl do get thick skin. (Pl don&#39;t take it otherwise)
# CSV file has been generated and saved as 'YouTube_Comments.csv'

# %% [markdown]
# ## Output as Pandas DataFrame

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyDyUNc6YYQGahMp6rjmxwMIWr83fY5x3V8"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="6RA-FtoUp-Y",
    maxResults=50
)
response = request.execute()

comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

df.head(10)

df.to_csv("YouTubeComments.csv", index=False)

# %%
df.head()
