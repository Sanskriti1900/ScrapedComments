# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanskriti1900/ScrapedComments/blob/main/YouTubeComments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pull Comments

# %%
import googleapiclient.discovery
import googleapiclient.errors
import pandas as pd # Import the pandas library

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyDyUNc6YYQGahMp6rjmxwMIWr83fY5x3V8"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="3obSZfvc91Q", # Corrected videoId
    maxResults=100
)
response = request.execute()

# Define an empty list called 'comments' to store the extracted comment data
comments = []

for item in response['items']:
    print(item['snippet']['topLevelComment']['snippet']['textDisplay'])
    # Extract the desired information from each comment and append it to the 'comments' list
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])


df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

df.to_csv("YouTubeComments.csv", index=False)

print("CSV file has been generated and saved as 'YouTube_Comments.csv'")

from google.colab import files
df.to_csv("YouTube_Comments.csv", index=False)
files.download("YouTube_Comments.csv")
# Out:
# Telegram Channel Link - <a href="https://telegram.me/+TQNB2vxJxpI3MWNi">https://telegram.me/+TQNB2vxJxpI3MWNi</a>
# ❤❤❤❤
# ❤
# Ye insan kisiko khush nahi rakh sakta mai nahi man sakti anyways rishi keep glowing nd growing truly happy and feeling inspired to see your new routine hope you are still trying to follow it❤
# Bhai behen ki ye bonding is so cute 🥰 and funny too 🤣😂❤❤ much love guys.......💟
# <a href="https://www.youtube.com/watch?v=3obSZfvc91Q&amp;t=832">13:52</a> ohhh God remind me of hidden love sang zhi wore the same
# I feel aunty and rishi is not happy 🙂🙂🙂🙂when aunty said that tum khush nhi ho💔🙂
# The same thing happened with my dad&#39;s WhatsApp. It got hacked. But OTP came after 8 days and I enabled the two step verification. We must do this..<br><br><br>And thi hacking happened as one day he got a voice call from unknown number (may be from another country) as soon as he received it his WhatsApp got hacked in few hours
# Daily vlog banaye
# 😂
# 😍😍😍😍😍
# ...

# %% [markdown]
# ## Output as Pandas DataFrame

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyDyUNc6YYQGahMp6rjmxwMIWr83fY5x3V8"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="6RA-FtoUp-Y",
    maxResults=50
)
response = request.execute()

comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])

df.head(10)

df.to_csv("YouTubeComments.csv", index=False)

# %%
df.head()
